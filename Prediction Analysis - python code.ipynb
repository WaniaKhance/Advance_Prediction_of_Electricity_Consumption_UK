# %%
#initialization of libraries
import numpy as np
import pandas as pd
#reading excel file into datafream using pandas
dataset = pd.read_excel('Dataset.xlsx')   
df = pd.DataFrame(dataset)
desc = df["Region"].describe() 
desc1 = df["Local Authority"].describe() 
#data description 
desc2 = df["Average_household_mean_kWh"].describe()
print(desc)
print(desc1)
desc2
# Out:
# count           2980
# unique            13
# top       South East
# freq             521
# Name: Region, dtype: object
# count           2980
# unique           399
# top       Inverclyde
# freq               8
# Name: Local Authority, dtype: object
# count     2980.000000
# mean      4162.749586
# std        723.077694
# min       2871.826597
# 25%       3700.407274
# 50%       4037.382037
# 75%       4476.888349
# max      10180.758234
# Name: Average_household_mean_kWh, dtype: float64

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
dataset = pd.read_excel('Dataset.xlsx')
df = pd.DataFrame(dataset)
#dataset first five samples
df.head()
# Out:
#    Year      Region Local Authority    LA Code     LAU1  E7_meters  \
# 0  2012  North East   County Durham  E06000047  UKC1400     10.602
# 1  2012  North East      Darlington  E06000005  UKC1300      4.100
# 2  2012  North East      Hartlepool  E06000001  UKC1101      2.316
# 3  2012  North East   Middlesbrough  E06000002  UKC1201      4.485
# 4  2012  North East  Northumberland  E06000057  UKC2100     15.237
#
#    Standard_meters  All_domestic_meters  All_Non-domestic_meters  \
# 0          226.480              237.082                   15.328
# 1           45.084               49.184                    3.478
# 2           39.870               42.186                    2.952
# 3           56.231               60.716                    4.126
# 4          135.598              150.835                   13.152
#
#    Total_meters  ...  Non-domestic_Mean_kWh  Non-domestic_Median_kWh  \
# 0       252.410  ...                75539.0                   8863.0
# ...

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np

dataset = pd.read_excel('Dataset.xlsx')
df = pd.DataFrame(dataset)
df2 = df.replace([np.inf, -np.inf], np.nan).dropna(axis=0)
#information about features data types
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 31 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Year                                  0 non-null      int64
#  1   Region                                0 non-null      object
#  2   Local Authority                       0 non-null      object
#  3   LA Code                               0 non-null      object
#  4   LAU1                                  0 non-null      object
#  5   E7_meters                             0 non-null      float64
#  6   Standard_meters                       0 non-null      float64
#  7   All_domestic_meters                   0 non-null      float64
#  8   All_Non-domestic_meters               0 non-null      float64
#  9   Total_meters                          0 non-null      float64
#  10  E7_GWh                                0 non-null      float64
# ...

# %%
#!pip install pingouin
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import pingouin as pg


dataset = pd.read_excel('Dataset.xlsx')
df = pd.DataFrame(dataset)
#anova testing for hypothesis testing
aov = pg.anova(dv = 'Average_household_mean_kWh', between = 'Region', data = df, detailed = True)
aov
# Out:
# F:\softwares\Anaconda\envs\keras_env\lib\site-packages\outdated\utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.11, the latest is 0.3.12.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
#    Source            SS    DF            MS          F          p-unc  \
# 0  Region  2.694264e+08    12  2.245220e+07  51.715513  4.097102e-113
# 1  Within  1.288118e+09  2967  4.341483e+05        NaN            NaN
#
#         np2
# 0  0.172982
# 1       NaN

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
import seaborn as sns
# read data from excel as pandas dataframe

dataset = pd.read_excel('Dataset.xlsx')
df = pd.DataFrame(data=dataset)
#selecting specific data features (numerical) from dataframe
df3 = df[["E7_meters", "Standard_meters","All_domestic_meters","All_Non-domestic_meters","Total_meters","E7_GWh","Standard_GWh",
           "All_domestic_GWh","All_non-domestic_GWh","Total_GWh","E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh", "Standard_Median_kWh", "Domestic_Mean_kWh",
           "Domestic_Median_kWh", "Non-domestic_Mean_kWh", "Non-domestic_Median_kWh", "Total_Mean_kWh", "Total_Median_kWh", "Average_household_mean_kWh", "Avg_CO2e_Kg"]]


#correlation between selected data features 
corrMatrix = df3.corr(method='pearson')
fig, ax = plt.subplots(figsize=(16,10))         
sns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax, cmap=plt.cm.RdYlGn_r)
plt.show()

#printing poorly correlated features with target variables
cor_target1 =corrMatrix["Average_household_mean_kWh"]
relevant_features = cor_target1[cor_target1<0.2]
print(relevant_features)
print('\n')

cor_target2 = corrMatrix["Avg_CO2e_Kg"]
relevant_features2 = cor_target2[cor_target2<0.2]
print(relevant_features2)
# Out:
# E7_meters                  0.058814
# Standard_meters           -0.322478
# All_domestic_meters       -0.282419
# All_Non-domestic_meters   -0.126391
# Total_meters              -0.271933
# Standard_GWh              -0.240392
# All_domestic_GWh          -0.149370
# All_non-domestic_GWh      -0.165418
# Total_GWh                 -0.170819
# Non-domestic_Mean_kWh     -0.169420
# Non-domestic_Median_kWh    0.051448
# Name: Average_household_mean_kWh, dtype: float64
#
#
# E7_meters                  0.077444
# Standard_meters           -0.224339
# All_domestic_meters       -0.189803
# All_Non-domestic_meters   -0.101628
# Total_meters              -0.184242
# E7_GWh                     0.185495
# Standard_GWh              -0.145672
# All_domestic_GWh          -0.075025
# All_non-domestic_GWh      -0.088772
# Total_GWh                 -0.089892
# Non-domestic_Mean_kWh     -0.048345
# Total_Mean_kWh             0.171050
# Name: Avg_CO2e_Kg, dtype: float64

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import metrics
# read data from url as pandas dataframe

dataset = pd.read_excel('Dataset.xlsx')
df = pd.DataFrame(data=dataset)
df3 = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh", "Standard_Median_kWh", "Domestic_Mean_kWh",
           "Domestic_Median_kWh", "Total_Median_kWh", "Average_household_mean_kWh", "Avg_CO2e_Kg"]]



corrMatrix = df3.corr(method='pearson')
fig, ax = plt.subplots(figsize=(13,10))         

sns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax, cmap=plt.cm.Reds)
plt.show()

#plotting and printing highly correlated data features
cor_target1 =corrMatrix["Average_household_mean_kWh"]
relevant_features = cor_target1[cor_target1>0.2]
print(relevant_features)
print('\n')

cor_target2 = corrMatrix["Avg_CO2e_Kg"]
relevant_features2 = cor_target2[cor_target2>0.2]
print(relevant_features2)
# Out:
# E7_Mean_kWh                   0.619930
# E7_Median_kWh                 0.617751
# Standard_Mean_kWh             0.761896
# Standard_Median_kWh           0.634182
# Domestic_Mean_kWh             0.891892
# Domestic_Median_kWh           0.815184
# Total_Median_kWh              0.858103
# Average_household_mean_kWh    1.000000
# Avg_CO2e_Kg                   0.734256
# Name: Average_household_mean_kWh, dtype: float64
#
#
# E7_Mean_kWh                   0.471083
# E7_Median_kWh                 0.491368
# Standard_Mean_kWh             0.653618
# Standard_Median_kWh           0.685486
# Domestic_Mean_kWh             0.709750
# Domestic_Median_kWh           0.754232
# Total_Median_kWh              0.765514
# Average_household_mean_kWh    0.734256
# Avg_CO2e_Kg                   1.000000
# Name: Avg_CO2e_Kg, dtype: float64

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# read data from url as pandas dataframe

dataset = pd.read_excel('Dataset.xlsx')
df = pd.DataFrame(data=dataset)
df3 = df[["E7_meters", "Standard_meters","All_domestic_meters","All_Non-domestic_meters","Total_meters","E7_GWh","Standard_GWh",
           "All_domestic_GWh","All_non-domestic_GWh","Total_GWh",
            "Non-domestic_Mean_kWh", "Non-domestic_Median_kWh", "Total_Mean_kWh", "Average_household_mean_kWh", "Avg_CO2e_Kg"]]


corrMatrix = df3.corr(method='pearson')
fig, ax = plt.subplots(figsize=(14,10))         

sns.heatmap(corrMatrix, annot=True, linewidths=.5, ax=ax, cmap=plt.cm.Greens)
plt.show()

#plotting and printing poorly correlated data features
cor_target1 =corrMatrix["Average_household_mean_kWh"]
relevant_features = cor_target1[cor_target1<0.5]
print(relevant_features)
print('\n')

cor_target2 = corrMatrix["Avg_CO2e_Kg"]
relevant_features2 = cor_target2[cor_target2<0.5]
print(relevant_features2)
# Out:
# E7_meters                  0.058814
# Standard_meters           -0.322478
# All_domestic_meters       -0.282419
# All_Non-domestic_meters   -0.126391
# Total_meters              -0.271933
# E7_GWh                     0.208315
# Standard_GWh              -0.240392
# All_domestic_GWh          -0.149370
# All_non-domestic_GWh      -0.165418
# Total_GWh                 -0.170819
# Non-domestic_Mean_kWh     -0.169420
# Non-domestic_Median_kWh    0.051448
# Total_Mean_kWh             0.240546
# Name: Average_household_mean_kWh, dtype: float64
#
#
# E7_meters                  0.077444
# Standard_meters           -0.224339
# All_domestic_meters       -0.189803
# All_Non-domestic_meters   -0.101628
# Total_meters              -0.184242
# E7_GWh                     0.185495
# Standard_GWh              -0.145672
# All_domestic_GWh          -0.075025
# All_non-domestic_GWh      -0.088772
# Total_GWh                 -0.089892
# Non-domestic_Mean_kWh     -0.048345
# ...

# %%
import sklearn.metrics as metrics
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm
from sklearn import metrics

#reading dataset from csv to dataframe using pandas

dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data=dataset)
X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Total_Median_kWh","Avg_CO2e_Kg"]]
y = df[["Average_household_mean_kWh"]]


#splitting dataset into training and testing samples
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

#model training on training data
lin_model = LinearRegression()
lin_model.fit(X_train, y_train)
 
# Model testing on testing data
y_pred = lin_model.predict(X_test)

print("                    Linear Regression Model            ")

#accuracy measure of model
# The coefficient of determination: 1 is perfect prediction
print('\nCoefficient of determination: ', r2_score(y_test, y_pred))

# The mean squared error
print('\nMean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))    


print("\n")
print ('Predicted Y value: ', lin_model.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3036, 1733]]))
print("\n")

#plotting predicted results of model with actual results
fig, ax = plt.subplots()
ax.scatter(y_test, y_pred)
ax.plot([y_train.min(), y_train.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
ax.set_xlabel('Measured Values')
ax.set_ylabel('Predicted Values')
ax.set_title(' Linear Regression ')
plt.show()

#use stats model for summary
X =  sm.add_constant(X)
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
print_model = model.summary()
print(print_model)
# Out:
#                     Linear Regression Model
#
# Coefficient of determination:  0.9217592191853621
#
# Mean Absolute Error: 131.91712135049016
# Mean Squared Error: 40118.372778480305
# Root Mean Squared Error: 200.29571333026652
#
#
# Predicted Y value:  [[3764.88043363]]
#                                 OLS Regression Results
# ...
# Dep. Variable:     Average_household_mean_kWh   R-squared:                       0.904
# Model:                                    OLS   Adj. R-squared:                  0.904
# Method:                         Least Squares   F-statistic:                     3514.
# Date:                        Fri, 28 May 2021   Prob (F-statistic):               0.00
# Time:                                09:03:11   Log-Likelihood:                -20349.
# No. Observations:                        2980   AIC:                         4.072e+04
# Df Residuals:                            2971   BIC:                         4.077e+04
# ...

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
import datetime
from sklearn import metrics


dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data=dataset)
X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Total_Median_kWh","Avg_CO2e_Kg"]]
y = df[["Average_household_mean_kWh"]]

X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size = 0.25, random_state = 42)

#model training

rf_model = RandomForestRegressor(n_estimators = 100, random_state = 0)

rf_model.fit(X_train2, y_train2)

#model testing
predictions = rf_model.predict(X_test2)
predictions=predictions.reshape(745,1)

errors = abs(predictions - y_test2)

print("                    Random Forest Regression Model            ")

#print('\n\nMean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

mape = 100 * (errors / y_test2)

accuracy = 100 - np.mean(mape)

#accuracy measure of model

print('\nCoefficient of determination:', r2_score(y_test2,predictions), '%.')

print('\nMean Absolute Error:', metrics.mean_absolute_error(y_test2, predictions))
print('Mean Squared Error:', metrics.mean_squared_error(y_test2, predictions))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test2, predictions)))    
print("\n")


print("\n")
print ('Predicted Y value: ', rf_model.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3036, 1733]]))
print("\n")

#plotting of predicted results and actual results
fig, ax = plt.subplots()
ax.scatter(y_test2, predictions)
ax.plot([y_train2.min(), y_train2.max()], [y_test2.min(), y_test2.max()], 'k--', lw=4)
ax.set_xlabel('Measured Values')
ax.set_ylabel('Predicted Values')
ax.set_title(' Random Forest Regression Classifier')
plt.show()
# Out:
# <ipython-input-10-9a3713ab704a>:26: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_model.fit(X_train2, y_train2)
#                     Random Forest Regression Model
#
# Coefficient of determination: 0.9595574954419398 %.
#
# Mean Absolute Error: 82.29754362416107
# Mean Squared Error: 16669.85558993289
# Root Mean Squared Error: 129.11179492956052
#
#
#
#
# Predicted Y value:  [3755.32]

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import svm
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics

dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data=dataset)
X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Total_Median_kWh","Avg_CO2e_Kg"]]
y = df[["Average_household_mean_kWh"]]

X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, test_size = 0.25, random_state = 10)


#model training and testing
DTR = DecisionTreeRegressor().fit(X_train3, y_train3)
predicted = DTR.predict(X_test3)
expected = y_test3



print("                    Decision Tree Regression Model           ")


#performance evaluation of model
print("\n\n Accuracy for Decision Tree Regression is ",r2_score(y_test3,predicted))  
 
print('\nMean Absolute Error:', metrics.mean_absolute_error(y_test3, predicted))
print('Mean Squared Error:', metrics.mean_squared_error(y_test3, predicted))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test3, predicted)))    


print("\n")
print ('Predicted Y value: ', DTR.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3036, 1733]]))
print("\n")


#plotting predicted results with actual results
fig, ax = plt.subplots()
ax.scatter(expected, predicted)
ax.plot([0, 7000], [0, 7000], 'k--', lw=4)
ax.set_xlabel('Measured Values')
ax.set_ylabel('Predicted Values')
ax.set_title('Decision Tree Regression')
plt.show()
# Out:
#                     Decision Tree Regression Model
#
#
#  Accuracy for Decision Tree Regression is  0.9160438024890616
#
# Mean Absolute Error: 115.44563758389262
# Mean Squared Error: 43404.18120805369
# Root Mean Squared Error: 208.33670153876798
#
#
# Predicted Y value:  [3613.]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.neighbors import KNeighborsRegressor

dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data = dataset)
X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Total_Median_kWh","Average_household_mean_kWh","Avg_CO2e_Kg"]]
y = df[["class"]]

X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size = 0.25, random_state = 10)

#model training and testing
clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train4, y_train4) 
y_pred = clf.predict(X_test4)


print("                  KNN Classification Model ")

#performance evaluation of model
print("\n\nAccuracy score for KNN:",metrics.accuracy_score(y_pred, y_test4))

print("\n")
print ('Predicted Y class: ', clf.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3036, 3766.60, 1733]]))
print("\n")

print("\n\n               Classification Report for KNN \n\n",classification_report(y_test4, y_pred))


#get the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test4, y_pred)
#turn this into a dataframe
matrix_df = pd.DataFrame(confusion_matrix)


#plot the result
ax = plt.axes()
sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")

ax.set_title('Confusion Matrix - KNN Classification')
ax.set_xlabel("Predicted Class", fontsize =15)
ax.set_ylabel("Actual Class", fontsize=15)
plt.show()

#model training and testing
logistic_regression_model = LogisticRegression(max_iter=1000)
logistic_regression_model.fit(X_train4,y_train4)
y_predicted = logistic_regression_model.predict(X_test4)

print ("\n\n                 Logistic Regression Classifier")
#performance evaluation of model
print('\n\nAccuracy rate of Logistic Regression: ',metrics.accuracy_score(y_test4, y_predicted))

print("\n")
print ('Predicted Y class: ', logistic_regression_model.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3036, 3766.60, 1733]]))
print("\n")

print("\n\n        Classification Report for Logistic Regression \n\n",classification_report(y_test4, y_predicted))

#get the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test4, y_predicted)
#turn this into a dataframe
matrix_df = pd.DataFrame(confusion_matrix)

#plot the result
ax = plt.axes()
sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
ax.set_title('Confusion Matrix - Logistic Regression Classifier')
ax.set_xlabel("Predicted Class", fontsize =15)
ax.set_ylabel("Actual Class", fontsize=15)
plt.show()
# Out:
#                   KNN Classification Model
#
#
# Accuracy score for KNN: 0.9758389261744966
#
#
# Predicted Y class:  [2]
#
#
#
#
#                Classification Report for KNN
#
#                precision    recall  f1-score   support
#
#            1       0.94      0.91      0.93       127
#            2       0.98      0.99      0.99       618
#
#     accuracy                           0.98       745
#    macro avg       0.96      0.95      0.96       745
# weighted avg       0.98      0.98      0.98       745
# F:\softwares\Anaconda\envs\keras_env\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from math import sqrt
from sklearn.tree import DecisionTreeClassifier  
import seaborn as sns

dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data = dataset)
X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Average_household_mean_kWh","Avg_CO2e_Kg"]]
y = df[["class"]]

X_train5, X_test5, y_train5, y_test5 = train_test_split(X, y, test_size = 0.25, random_state = 10)

#model training and testing on dataset
dt_model= DecisionTreeClassifier(criterion='entropy', random_state=0)  
dt_model.fit(X_train5, y_train5) 
y_pred1= dt_model.predict(X_test5) 

print("               Decision Tree Classification ")

#performance evaluation of model
print("\n\nAccuracy score for Decision Tree Classification Model:",metrics.accuracy_score(y_pred1, y_test5))

print("\n")
print ('Predicted Y class: ', dt_model.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3766.60, 1733]]))


print("\n\n               Classification Report \n\n",classification_report(y_test5, y_pred1))

#get the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test5, y_pred1)
#turn this into a dataframe
matrix_df = pd.DataFrame(confusion_matrix)
#plot the result

ax = plt.axes()
sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
ax.set_title('Confusion Matrix - Decision Tree Classification')
ax.set_xlabel("Predicted Class", fontsize =15)
ax.set_ylabel("Actual Class", fontsize=15)
plt.show()
# Out:
#                Decision Tree Classification
#
#
# Accuracy score for Decision Tree Classification Model: 0.9838926174496644
#
#
# Predicted Y class:  [2]
#
#
#                Classification Report
#
#                precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95       127
#            2       0.99      0.99      0.99       618
#
#     accuracy                           0.98       745
#    macro avg       0.97      0.97      0.97       745
# weighted avg       0.98      0.98      0.98       745

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
from sklearn.model_selection import cross_val_score
import seaborn as sns
from sklearn.svm import SVC


dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data = dataset)

X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Average_household_mean_kWh","Avg_CO2e_Kg"]]
y = df[["class"]]

X_train6, X_test6, y_train6, y_test6 = train_test_split(X, y, test_size = 0.25, random_state = 10)

#model training
SVC_model = SVC(kernel='linear')
SVC_model.fit(X_train6, y_train6)
#model testing
y_pred2 = SVC_model.predict(X_test6)
print("               SVM Classification Prediction Analysis ")

#performance evaluation

print("\nAccuracy score for SVM Classifier:",metrics.accuracy_score(y_pred2, y_test6))

print("\n")
print ('Predicted Y class: ', SVC_model.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3766.60, 1733]]))


print("\n\n               Classification Report for SVM \n\n",classification_report(y_test6, y_pred2))

#get the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test6, y_pred2)
#turn this into a dataframe
matrix_df = pd.DataFrame(confusion_matrix)
#plot the result


print("\n")
ax = plt.axes()
sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
ax.set_title('Confusion Matrix - SVM Classification')
ax.set_xlabel("Predicted Class", fontsize =15)
ax.set_ylabel("True Class", fontsize=15)
plt.show()
# Out:
# F:\softwares\Anaconda\envs\keras_env\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#                SVM Classification Prediction Analysis
#
# Accuracy score for SVM Classifier: 0.9825503355704698
#
#
# Predicted Y class:  [2]
#
#
#                Classification Report for SVM
#
#                precision    recall  f1-score   support
#
#            1       0.97      0.92      0.95       127
#            2       0.98      1.00      0.99       618
#
#     accuracy                           0.98       745
#    macro avg       0.98      0.96      0.97       745
# weighted avg       0.98      0.98      0.98       745

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics
import seaborn as sns
from sklearn.naive_bayes import GaussianNB

dataset = pd.read_csv('Dataset.csv',encoding='cp1252')
df = pd.DataFrame(data = dataset)
df2 = df.replace([np.inf, -np.inf], np.nan).dropna(axis=0)


X = df2[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Average_household_mean_kWh","Avg_CO2e_Kg"]]
y = df2[["class"]]

X_train7, X_test7, y_train7, y_test7 = train_test_split(X, y, test_size = 0.25, random_state = 10)

#model training and testing 

nb_model = GaussianNB()

#Train the model using the training sets
nb_model.fit(X_train7, y_train7)

#Predict the response for test dataset
y_pred3 = nb_model.predict(X_test7)

print("                     Gaussian Naivebayes Classifier")

#performance evaluation of model
print("\nAccuracy for Gaussian Naivebayes: ",metrics.accuracy_score(y_test7, y_pred))
print("\n")
print ('Predicted Y class: ', nb_model.predict([[5459, 4257, 3385, 2913, 3558, 2968, 3766.60, 1733]]))

print("\n\n               Classification Report for Gaussain NB \n\n",classification_report(y_test7, y_pred3))

#get the confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test7, y_pred3)
#turn this into a dataframe
matrix_df = pd.DataFrame(confusion_matrix)
#plot the result


print("\n")
ax = plt.axes()
sns.set(font_scale=1.3)
plt.figure(figsize=(10,7))
sns.heatmap(matrix_df, annot=True, fmt="g", ax=ax, cmap="magma")
ax.set_title('Confusion Matrix - Gaussian NB')
ax.set_xlabel("Predicted Class", fontsize =15)
ax.set_ylabel("True Class", fontsize=15)
plt.show()
# Out:
#                      Gaussian Naivebayes Classifier
#
# Accuracy for Gaussian Naivebayes:  0.9758389261744966
#
#
# Predicted Y class:  [2]
#
#
#                Classification Report for Gaussain NB
#
#                precision    recall  f1-score   support
#
#            1       0.72      0.97      0.83       127
#            2       0.99      0.92      0.96       618
#
#     accuracy                           0.93       745
#    macro avg       0.86      0.95      0.89       745
# weighted avg       0.95      0.93      0.93       745
# F:\softwares\Anaconda\envs\keras_env\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)

# %%
import keras 
from keras.layers import Dense
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from sklearn.preprocessing import StandardScaler
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split

df= pd.read_csv('Dataset.csv',encoding='cp1252')
df.dropna(inplace=True)

X = df[["E7_Mean_kWh","E7_Median_kWh","Standard_Mean_kWh","Standard_Median_kWh","Domestic_Mean_kWh",
             "Domestic_Median_kWh","Average_household_mean_kWh"]]

y = df[['Avg_CO2e_Kg']]

xtrain,xtest,ytrain,testY=train_test_split(X,y,test_size=0.25, random_state=42)
#scaling input features
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.fit_transform(xtest)

#converting data array into matrix form
def convert2matrix(data_arr, look_back):
    X, Y =[], []
    for i in range(len(data_arr)-look_back):
        d=i+look_back 
        X.append(data_arr[i:d,0])
        Y.append(data_arr[d,0])
    return np.array(X), np.array(Y)
    

look_back = 90
trainX, trainY = convert2matrix(xtrain, look_back)
testX, testY = convert2matrix(xtest, look_back)

#model preparing

def model_dnn(look_back):
    model=Sequential()
    model.add(Dense(units=22, input_dim=look_back, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(8, activation='relu'))
    #model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',  optimizer='adam',metrics = ['mse', 'mae','accuracy'])
    return model
    
#model testing    
model=model_dnn(look_back)
history=model.fit(trainX,trainY, epochs=200, batch_size=30, verbose=1, validation_data=(testX,testY),shuffle=False)
# Out:
# Epoch 1/200
# 72/72 [==============================] - 0s 5ms/step - loss: 2.0532 - mse: 2.0532 - mae: 1.1189 - accuracy: 0.0000e+00 - val_loss: 1.2282 - val_mse: 1.2282 - val_mae: 0.8962 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 72/72 [==============================] - 0s 1ms/step - loss: 1.4376 - mse: 1.4376 - mae: 0.9346 - accuracy: 0.0000e+00 - val_loss: 1.0739 - val_mse: 1.0739 - val_mae: 0.8299 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 72/72 [==============================] - 0s 991us/step - loss: 1.1989 - mse: 1.1989 - mae: 0.8577 - accuracy: 0.0000e+00 - val_loss: 1.0186 - val_mse: 1.0186 - val_mae: 0.8001 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 72/72 [==============================] - 0s 1ms/step - loss: 1.1032 - mse: 1.1032 - mae: 0.8288 - accuracy: 0.0000e+00 - val_loss: 1.0020 - val_mse: 1.0020 - val_mae: 0.7912 - val_accuracy: 0.0000e+00
# Epoch 5/200
# ...

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)


print("\n\n","                    Deep Neural Network Implementation  \n\n")

#plotting training and validation loss on each epoch
def model_loss(history):
    plt.figure(figsize=(8,4))
    plt.plot(epochs, loss, label='Train Loss')
    plt.plot(epochs, val_loss, label='Validation Loss')
    plt.title('Training and Validation loss')
    plt.ylabel('Loss', size=15)
    plt.xlabel('Epochs', size=15)
    plt.legend(loc='upper right')
    plt.show();

#performance evaluation of model
train_score = model.evaluate(trainX, trainY, verbose=0)
print('Train Root Mean Squared Error(RMSE): %.2f; Train Mean Absolute Error(MAE) : %.2f ' 
% (np.sqrt(train_score[1]), train_score[2]))
test_score = model.evaluate(testX, testY, verbose=0)
print('Test Root Mean Squared Error(RMSE): %.2f; Test Mean Absolute Error(MAE) : %.2f ' 
% (np.sqrt(test_score[1]), test_score[2]))
model_loss(history)

#model testing
train_predict = model.predict(trainX)
test_predict = model.predict(testX) 

#plotting actual and predicted results of model on graph
def prediction_plot(testY, test_predict):
    len_prediction=[x for x in range(len(testY))]
    plt.figure(figsize=(8,4))
    test_predict =test_predict[:,0]
    plt.plot(len_prediction, testY, marker='.', label="actual")
    plt.plot(len_prediction, test_predict, 'r', label="prediction")
    #plt.legend(loc='upper right')
    plt.tight_layout()
    sns.despine(top=True)
    #plt.subplots_adjust(left=0.07)
    plt.ylabel('Average Co2 Emission _Scaled', size=15)
    plt.xlabel('Time step', size=18)
    plt.legend(fontsize=11)
    plt.show();
    
prediction_plot(testY, test_predict)
# Out:
#                      Deep Neural Network Implementation
#
#
# Train Root Mean Squared Error(RMSE): 0.73; Train Mean Absolute Error(MAE) : 0.58
# Test Root Mean Squared Error(RMSE): 1.10; Test Mean Absolute Error(MAE) : 0.89
